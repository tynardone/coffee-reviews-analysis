# %%
import pandas as pd
import lxml

# %%
tables = pd.read_html('https://nuforc.org/webreports/ndxlCT.html')

# %%
len(tables)
# Out:
# 1

# %%
df = tables[0]

# %%
df
# Out:
#            Date / Time           City State Country      Shape  \
# 0        7/24/23 20:02        Enfield    CT     USA  Formation
# 1        7/23/23 10:45      New Haven    CT     USA  Rectangle
# 2        7/14/23 21:00      New haven    CT     USA  Rectangle
# 3        7/14/23 05:00      Fairfield    CT     USA        Orb
# 4        7/13/23 20:21    North haven    CT     USA      Cigar
# ...                ...            ...   ...     ...        ...
# 1977      2/3/51 22:00  Thompsonville    CT     USA       Disk
# 1978      6/4/49 10:00    Los Angeles    CT     USA     Circle
# 1979             22:00      Stratford    CT     USA    Unknown
# 1980  01/23/20×0 20:00        Tolland    CT     USA      Other
# 1981      1980's 17:00        Danbury    CT     USA       Oval
#
#                Duration                                            Summary  \
# 0     Approx 60 seconds                               3 craft in formation
# ...

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['figure.dpi']= 300

# %%
notes_section = pd.read_csv('../../data/raw/notes-section.csv')
openrefine = pd.read_csv('../../data/interim/05042024-roast-review-openrefine.csv')
notes_section_filtered = notes_section.loc[:, ['url', 'notes']]

# %%
merged = (pd
          .merge(openrefine, notes_section_filtered, on='url', how='inner')
          .drop(columns=['notes_x'])
          .rename(columns={"notes_y":"notes"})
          .drop_duplicates("url")
)

# %%
# set max row width for dataframe


merged.sample(10)
# Out:
#       rating                roaster  \
# 1579      96          Kakalove Cafe
# 2996      96      Paradise Roasters
# 2777      92                 A.R.C.
# 2520      90  Temple Coffee and Tea
# 3700      94     Wonderstate Coffee
# 5193      92     Wonderstate Coffee
# 4972      87  Green Mountain Coffee
# 2716      91    JBC Coffee Roasters
# 4903      91            Just Coffee
# 942       94          Regent Coffee
#
#                                                 title  \
# 1579  Panama Boquete Flor De Mariposa Geisha Espresso
# 2996                  Hawaii Kilauea Volcano Nano-Lot
# 2777                   Ethiopia Yirgacheffe Washed G1
# 2520                        Costa Rica Francisco Ruiz
# 3700                  Organic Ethiopian Banko Natural
# 5193                                 Organic Colombia
# 4972                                        Our Blend
# 2716                                Gaitania Colombia
# 4903                 Ethiopia Yirgacheffe Light Roast
# ...

# %%
# Out:
# (7740, 20)

# %%
notes_section.dropna(subset="est_price").shape
# Out:
# (5710, 20)

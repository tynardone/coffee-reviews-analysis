# %% [markdown]
# # Coffee Review Cleaning and EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Clean
# - review date to date dtype
# - acidity/structure & acidity into one column
# - agtron into 2 columns
# - split origin and roasdter locations into columns for states and country
# - price into float
# - maybe: roaster into cat, location into cat
# - aroma, acidity, body, flavor, aftertaste, agtron's into int
# - drop NA
#
# ### EDA ideas
# - visualize histograms
# - visualize correlations
# - word clouds
# - tokenize descriptions
# - plot locations, roasters, roast level, agtron vs other characterisitcs
# - cluster analysis
# - standardize ratings??

# %%
# Read in raw coffee review data
df = pd.read_csv('data/raw-roast-reviews.csv')
df.head()

def tweak_coffee(df):
    return (df
            .rename(columns = lambda c: c.replace(' ', '_'))
            .rename(columns = {'Coffee_Origin': 'Origin',
                               'Est._Price': 'Price'})
            .assign(Review_Date = pd.to_datetime(df['Review_Date'], format='%b %Y'),
                    Acidity = lambda df_: df_['Acidity/Structure'].fillna(df_['Acidity']),
                    Agtron_External = lambda df_: df_['Agtron'].str.split('/', expand=True)[0],
                    Agtron_Ground = lambda df_: df_['Agtron'].str.split('/', expand=True)[1],
                    Price = lambda df_: df_['Price'].str.replace(',', ''),
                     )
            .applymap(lambda x: x.strip() if isinstance(x, str) else x)
            .applymap(lambda x: np.nan if x == 'NA' else x)
            .drop(['Acidity/Structure', 'Agtron'], axis=1)
            .dropna(subset=['Acidity', 'Roast_Level', 'Aroma', 'Price', 'Bottom_Line', 
                            'Agtron_External', 'Agtron_Ground'])
            .astype({'Roaster': 'category', 'Rating': 'int64', 'Roast_Level':'category',
                     'Roaster_Location':'category',
                     'Agtron_External':'int64', 'Agtron_Ground':'int64',
                     'Aftertaste': 'int64', 'Aroma': 'int64', 'Body': 'int64',
                     'Flavor': 'int64', 'Acidity': 'int64', 'Review_Date': 'datetime64[ns]'
                     })
            
           )

coffee = tweak_coffee(df)
coffee.sample(5)
# Out:
#       Rating                Roaster                   Coffee_Name Review_Date  \
# 27        95            Speckled Ax        Sumatra Lintong Kardon  2023-08-01
# 1262      94    JBC Coffee Roasters           Las Flores Colombia  2021-06-01
# 1958      92    JBC Coffee Roasters        San Sebastian Colombia  2020-02-01
# 1175      93  Peach Coffee Roasters               Sumatra Lintong  2021-08-01
# 111       92          Mostra Coffee  Philippine Rosemarie Rupecio  2023-07-01
#
#                                      Review_Description  \
# 27    Richly earthy, deeply spice-toned. Graphite, p...
# 1262  Sweet, bright, elegant. Dark chocolate, hazeln...
# 1958  Soft, deep, crisply chocolaty. Baking chocolat...
# 1175  Sweetly savory, deep-toned. Pipe tobacco, sand...
# 111   Sweetly nut-toned, richly bittersweet. Almond ...
#
#                                     Complete_Review_URL  \
# 27    https://www.coffeereview.com/review/sumatra-li...
# 1262  https://www.coffeereview.com/review/las-flores...
# 1958  https://www.coffeereview.com/review/san-sebast...
# 1175  https://www.coffeereview.com/review/sumatra-li...
# 111   https://www.coffeereview.com/review/philippine...
#
#                                     Roaster_Website_URL  \
# 27                                                  NaN
# 1262  https://www.jbccoffeeroasters.com/product-cate...
# 1958  https://www.jbccoffeeroasters.com/product-cate...
# 1175                                                NaN
# 111         https://mostracoffee.com/collections/coffee
#
#            Roaster_Location  \
# 27          Portland, Maine
# 1262     Madison, Wisconsin
# 1958     Madison, Wisconsin
# 1175   Johns Creek, Georgia
# 111   San Diego, California
#
#                                                  Origin   Roast_Level  ...  \
# 27    Lintong growing region, North Sumatra Province...  Medium-Light  ...
# 1262               San Isidro, Acevedo, Huila, Colombia  Medium-Light  ...
# 1958            Huila Department, southwestern Colombia  Medium-Light  ...
# 1175  Lintong growing region, North Sumatra Province...  Medium-Light  ...
# 111   Sitio Pluto, Balutakay, Managa, Davao del Sur,...        Medium  ...
#
#       Body  Flavor  Aftertaste  \
# 27       9       9           9
# 1262     9       9           8
# 1958     9       9           8
# 1175     9       9           8
# 111      8       9           8
#
#                                        Blind_Assessment  \
# 27    Richly earthy, deeply spice-toned. Graphite, p...
# 1262  Sweet, bright, elegant. Dark chocolate, hazeln...
# 1958  Soft, deep, crisply chocolaty. Baking chocolat...
# 1175  Sweetly savory, deep-toned. Pipe tobacco, sand...
# 111   Sweetly nut-toned, richly bittersweet. Almond ...
#
#                                                   Notes  \
# 27    Produced by 200 widows with support and traini...
# 1262  Produced by Jhoan Manuel Vergara Ayure of Finc...
# 1958  Produced by small-holding farmers with the sup...
# 1175  Coffees from the northern part of the Indonesi...
# 111   Produced by Rosemarie Rupecio of the BACOFA Co...
#
#                                             Bottom_Line             Price  \
# 27    A classic Sumatra cup that highlights the orig...  $21.00/12 ounces
# 1262  A deep, chocolaty Colombia cup with ballast fr...  $20.00/12 ounces
# 1958  A big-bodied Colombia driven by crisp chocolat...  $17.75/12 ounces
# 1175  A classic Sumatra profile: rich, deep, sweetly...  $18.99/12 ounces
# 111   A honey-processed Philippine coffee, deeply sw...  $34.99/12 ounces
#
#                                                     url Agtron_External  \
# 27    https://www.coffeereview.com/review/sumatra-li...              56
# 1262  https://www.coffeereview.com/review/las-flores...              58
# 1958  https://www.coffeereview.com/review/san-sebast...              59
# 1175  https://www.coffeereview.com/review/sumatra-li...              54
# 111   https://www.coffeereview.com/review/philippine...              53
#
#      Agtron_Ground
# 27              74
# 1262            78
# 1958            76
# 1175            72
# 111             65
#
# [5 rows x 22 columns]

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2095 entries, 0 to 2453
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rating               2095 non-null   int64
#  1   Roaster              2095 non-null   category
#  2   Coffee_Name          2095 non-null   object
#  3   Review_Date          2095 non-null   datetime64[ns]
#  4   Review_Description   2095 non-null   object
#  5   Complete_Review_URL  2095 non-null   object
#  6   Roaster_Website_URL  1265 non-null   object
#  7   Roaster_Location     2095 non-null   category
#  8   Origin               2095 non-null   object
#  9   Roast_Level          2095 non-null   category
#  10  Aroma                2095 non-null   int64
#  11  Acidity              2095 non-null   int64
#  12  Body                 2095 non-null   int64
#  13  Flavor               2095 non-null   int64
#  14  Aftertaste           2095 non-null   int64
#  15  Blind_Assessment     2095 non-null   object
#  16  Notes                2095 non-null   object
#  17  Bottom_Line          2095 non-null   object
#  18  Price                2095 non-null   object
#  19  url                  2095 non-null   object
#  20  Agtron_External      2095 non-null   int64
#  21  Agtron_Ground        2095 non-null   int64
# dtypes: category(3), datetime64[ns](1), int64(8), object(10)
# memory usage: 367.5+ KB

# %%
pattern_1 = r'([A-Za-z¥£$]+)\s*([\d,.]+)'
pattern_2 = r'(\d+(?:,\d+)?)\s*(\w+)'

price_unit = (coffee['Price']
              .str.split('/', n=1, expand=True)
              .assign(currency = lambda df_: df_[0].str.extract(pattern_1)[0],
                      price = lambda df_: df_[0].str.extract(pattern_1)[1].str.replace(',', '')
                                                  .str.strip().astype('float'),
                      amount = lambda df_: df_[1].str.extract(pattern_2)[0],
                      unit = lambda df_: df_[1].str.extract(pattern_2)[1]
                       )
              .drop([0, 1], axis=1)
              .dropna(axis=0)
              .astype({'amount': 'int64', 'price':'float'}
                       )
             )

# NT$ - taiwan
# £ - british pound 
# ¥ -  Chinese Yuan
# pesos - mexican
# CAD - canadian
price_unit['currency'].value_counts()

mapping_dict = {'$NT$': 'NT$', '$NT':'NT$'}
price_unit['currency'] = price_unit['currency'].replace(mapping_dict)

price_unit
# Out:
#      currency  price  amount    unit
# 0           $  22.00       8  ounces
# 1           $  22.00       8  ounces
# 2           $  22.00       8  ounces
# 3           $  22.00       8  ounces
# 8           $  18.00      12  ounces
# ...       ...    ...     ...     ...
# 2445        $  13.34       4  ounces
# 2446        $  13.34       4  ounces
# 2448        $  18.00      12  ounces
# 2452        $  14.99      12  ounces
# 2453        $  22.15     500   grams
#
# [2085 rows x 4 columns]

# %%
df.head()
# Out:
#    Rating              Roaster           Coffee_Name Review_Date  \
# 0      94  JBC Coffee Roasters  Wilton Benitez Sidra    Aug 2023
# 1      94  JBC Coffee Roasters  Wilton Benitez Sidra    Aug 2023
# 2      94  JBC Coffee Roasters  Wilton Benitez Sidra    Aug 2023
# 3      94  JBC Coffee Roasters  Wilton Benitez Sidra    Aug 2023
# 4      93  JBC Coffee Roasters  Twisted V.8 Espresso    Aug 2023
#
#                                   Review_Description  \
# 0  Delicately fruity, richly floral-toned. Froot ...
# 1  Delicately fruity, richly floral-toned. Froot ...
# 2  Delicately fruity, richly floral-toned. Froot ...
# 3  Delicately fruity, richly floral-toned. Froot ...
# 4  Evaluated as espresso. Chocolaty, fruity, nutt...
#
#                                  Complete_Review_URL  \
# 0  https://www.coffeereview.com/review/wilton-ben...
# 1  https://www.coffeereview.com/review/wilton-ben...
# 2  https://www.coffeereview.com/review/wilton-ben...
# 3  https://www.coffeereview.com/review/wilton-ben...
# 4  https://www.coffeereview.com/review/twisted-v-...
#
#                                  Roaster_Website_URL    Roaster Location  \
# 0  https://www.jbccoffeeroasters.com/product-cate...  Madison, Wisconsin
# 1  https://www.jbccoffeeroasters.com/product-cate...  Madison, Wisconsin
# 2  https://www.jbccoffeeroasters.com/product-cate...  Madison, Wisconsin
# 3  https://www.jbccoffeeroasters.com/product-cate...  Madison, Wisconsin
# 4  https://www.jbccoffeeroasters.com/product-cate...  Madison, Wisconsin
#
#                           Coffee Origin   Roast Level  ...  Acidity  Body  \
# 0  Piendamó, Cauca Department, Colombia  Medium-Light  ...      NaN   9.0
# 1  Piendamó, Cauca Department, Colombia  Medium-Light  ...      NaN   9.0
# 2  Piendamó, Cauca Department, Colombia  Medium-Light  ...      NaN   9.0
# 3  Piendamó, Cauca Department, Colombia  Medium-Light  ...      NaN   9.0
# 4     South and Central America; Africa  Medium-Light  ...      NaN   8.0
#
#    Flavor  Aftertaste  Agtron  \
# 0     9.0         8.0   58/74
# 1     9.0         8.0   58/74
# 2     9.0         8.0   58/74
# 3     9.0         8.0   58/74
# 4     9.0         8.0   54/72
#
#                                     Blind Assessment  \
# 0  Delicately fruity, richly floral-toned. Froot ...
# 1  Delicately fruity, richly floral-toned. Froot ...
# 2  Delicately fruity, richly floral-toned. Froot ...
# 3  Delicately fruity, richly floral-toned. Froot ...
# 4  Evaluated as espresso. Chocolaty, fruity, nutt...
#
#                                                Notes  \
# 0  Produced by Wilton Benitez, entirely of the Si...
# 1  Produced by Wilton Benitez, entirely of the Si...
# 2  Produced by Wilton Benitez, entirely of the Si...
# 3  Produced by Wilton Benitez, entirely of the Si...
# 4  A blend of coffees from undisclosed South and ...
#
#                                          Bottom Line        Est. Price  \
# 0  A complex, deep-toned, very fruit-forward anae...   $22.00/8 ounces
# 1  A complex, deep-toned, very fruit-forward anae...   $22.00/8 ounces
# 2  A complex, deep-toned, very fruit-forward anae...   $22.00/8 ounces
# 3  A complex, deep-toned, very fruit-forward anae...   $22.00/8 ounces
# 4  A very chocolaty espresso blend with lift from...  $18.00/12 ounces
#
#                                                  url
# 0  https://www.coffeereview.com/review/wilton-ben...
# 1  https://www.coffeereview.com/review/wilton-ben...
# 2  https://www.coffeereview.com/review/wilton-ben...
# 3  https://www.coffeereview.com/review/wilton-ben...
# 4  https://www.coffeereview.com/review/twisted-v-...
#
# [5 rows x 22 columns]

# %%
df[df['url'] == 'https://www.coffeereview.com/review/guatemala-acatenango-gesha-7/']
# Out:
#      Rating                         Roaster                 Coffee_Name  \
# 254      94  Lin Jen-Wei’s Black Jar Coffee  Guatemala Acatenango Gesha
#
#     Review_Date                                 Review_Description  \
# 254    Mar 2023  Floral, balanced, deep-toned. Star jasmine, Bi...
#
#                                    Complete_Review_URL Roaster_Website_URL  \
# 254  https://www.coffeereview.com/review/guatemala-...                 NaN
#
#      Roaster Location                         Coffee Origin Roast Level  ...  \
# 254  Taichung, Taiwan  Acatenango growing region, Guatemala       Light  ...
#
#      Acidity  Body  Flavor  Aftertaste  Agtron  \
# 254      NaN   9.0     9.0         8.0   67/86
#
#                                       Blind Assessment  \
# 254  Floral, balanced, deep-toned. Star jasmine, Bi...
#
#                                                  Notes  \
# 254  Produced entirely of the Gesha (also Geisha) v...
#
#                                            Bottom Line           Est. Price  \
# 254  A lovely Guatemala Gesha cup with bright stone...  NT $1,200/227 grams
#
#                                                    url
# 254  https://www.coffeereview.com/review/guatemala-...
#
# [1 rows x 22 columns]
